# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# file_method = open("data/data_method.csv")
# file_group = open("data/data_group.scv")

# file_method = pd.read_csv("data/data_method.csv",na_values=" NaN")
# file_method = file_method.dropna(how='all', axis=1)
# file_group = pd.read_csv("data/data_group.csv",na_values=" NaN")
# file_group = file_group.dropna(how='all', axis=1)
# print(file_method)
# print(file_group)

file_method_grouping = pd.read_csv("statistical_results/data_method_grouping.csv",na_values=" NaN")
file_method_grouping = file_method_grouping.dropna(how='all', axis=1)
file_group_grouping = pd.read_csv("statistical_results/data_group_grouping.csv",na_values=" NaN")
file_group_grouping = file_group_grouping.dropna(how='all', axis=1)
print(file_method_grouping)
print(file_group_grouping)
# Out:
#                     plot     score pair method
# 0    gesture_distinction  5.000000    A   none
# 1    gesture_distinction  5.000000    A   none
# 2    gesture_distinction  4.384615    A   none
# 3    gesture_distinction  4.625000    A   none
# 4    gesture_distinction  4.541667    A   none
# ..                   ...       ...  ...    ...
# 175          naturalness  5.000000    C   full
# 176          naturalness  4.777778    C   full
# 177          naturalness  5.000000    C   full
# 178          naturalness  4.200000    C   full
# 179          naturalness  4.363636    C   full
#
# [180 rows x 4 columns]
#    q2_m1_g1  q3_m1_g1  q4_m1_g1  q2_m1_g2  q3_m1_g2  q4_m1_g2  q2_m2_g1  \
# 0  5.000000  4.500000  4.500000  5.000000  4.555556  3.888889  5.000000
# 1  5.000000  4.666667  4.933333  5.000000  4.800000  5.000000  4.857143
# 2  4.428571  4.476190  3.809524  4.200000  4.400000  4.200000  4.800000
# 3  4.631579  4.631579  4.842105  4.600000  4.400000  4.600000  5.000000
# ...

# %%
print(file_method.q2_m3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(file_method.q2_m3)
#
# NameError: name 'file_method' is not defined

# %%
fig = plt.figure(figsize = (10,7))
ax = fig.add_subplot(111)
plt.show()

# %%
# https://stackoverflow.com/questions/16592222/matplotlib-group-boxplots

#-------------A: method-wilcoxon----------------
# gesture_distinction (m1,m2) (m1,m3) (m2,m3)



data1 = file_method_grouping.loc[file_method_grouping['plot'] == 'gesture_distinction']
data1.score = data1.score * 7 /5
fig1 = plt.figure(figsize = (10,7))
plt.ylim(3, 8)
sns.set(style="ticks", palette='Set3')
sns.set_style("whitegrid")
sns.boxplot(x='pair', y='score', hue='method', data=data1)
plt.legend(loc='lower center', title="Method", fontsize= 14)
plt.title('gesture_distinction',fontdict = {'fontsize' : 20})
# Out:
# C:\Users\motionlab_3080\AppData\Local\Temp\ipykernel_6800\687841729.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.score = data1.score * 7 /5
# Text(0.5, 1.0, 'gesture_distinction')

# %%
# # target_distinction (m1,m2) (m1,m3) (m2,m3)
data2 = file_method_grouping.loc[file_method_grouping['plot'] == 'target_distinction']
data2.score = data2.score * 7 /5
fig2 = plt.figure(figsize = (10,7))
plt.ylim(3, 8)
sns.set(style="ticks", palette='Set3')
sns.set_style("whitegrid")
sns.boxplot(x='pair', y='score', hue='method', data=data2)
plt.legend(loc='lower center', title="Method", fontsize= 14)
plt.title('target_distinction',fontdict = {'fontsize' : 20})
# Out:
# C:\Users\motionlab_3080\AppData\Local\Temp\ipykernel_6800\2880961622.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.score = data2.score * 7 /5
# Text(0.5, 1.0, 'target_distinction')

# %%
# # naturalness (m1,m2) (m1,m3) (m2,m3)
data3 = file_method_grouping.loc[file_method_grouping['plot'] == 'naturalness']
data3.score = data3.score * 7 /5
fig3 = plt.figure(figsize = (10,7))
plt.ylim(3, 8)
sns.set(style="ticks", palette='Set3')
sns.set_style("whitegrid")
sns.boxplot(x='pair', y='score', hue='method', data=data3)
plt.legend(loc='lower center', title="Method", fontsize= 14)
plt.title('naturalness',fontdict = {'fontsize' : 20})
# Out:
# C:\Users\motionlab_3080\AppData\Local\Temp\ipykernel_6800\1693926289.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.score = data3.score * 7 /5
# Text(0.5, 1.0, 'naturalness')

# %%
#------------B: group-friedman-----------------
# gesture (g1, g2), target (g1, g2), naturalness (g1, g2)
data = pd.read_csv("statistical_results/data_group_grouping_friedman.csv",na_values=" NaN")
data = data.dropna(how='all', axis=1)


fig = plt.figure(figsize = (10,7))
plt.ylim(0, 6)
sns.set(style="ticks", palette='pastel')
sns.set_style("whitegrid")
sns.boxplot(x='Question', y='Likert Score (1-5)', hue='group', data=data)
plt.legend(loc='lower center', title="gesture sequence", fontsize= 14)
plt.title('Single Vs Sequential animation',fontdict = {'fontsize' : 20})
# Out:
# Text(0.5, 1.0, 'Single Vs Sequential animation')

# %%
#------------C: group-wilcoxon-----------------
# gesture (m1)(g1,g2) (m2)(g1,g2) (m3)(g1,g2)
# target (m1)(g1,g2)* (m2)(g1,g2) (m3)(g1,g2)
# naturalness (m1)(g1,g2) (m2)(g1,g2) (m3)(g1,g2)
data = pd.read_csv("statistical_results/data_group_grouping_wilcoxon.csv",na_values=" NaN")
data = data.dropna(how='all', axis=1)

data1 = data.loc[data['Question'] == 'gesture_distinction']
data2 = data.loc[data['Question'] == 'target_distinction']
data3 = data.loc[data['Question'] == 'naturalness']
data1['Likert Score (1-5)'] = data1['Likert Score (1-5)'] * 7 /5
data2['Likert Score (1-5)'] = data2['Likert Score (1-5)'] * 7 /5
data3['Likert Score (1-5)'] = data3['Likert Score (1-5)'] * 7 /5
# Out:
# C:\Users\motionlab_3080\AppData\Local\Temp\ipykernel_6800\1107997817.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Likert Score (1-5)'] = data1['Likert Score (1-5)'] * 7 /5
# C:\Users\motionlab_3080\AppData\Local\Temp\ipykernel_6800\1107997817.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['Likert Score (1-5)'] = data2['Likert Score (1-5)'] * 7 /5
# C:\Users\motionlab_3080\AppData\Local\Temp\ipykernel_6800\1107997817.py:13: SettingWithCopyWarning:
# ...

# %%
fig = plt.figure(figsize = (10,7))
plt.ylim(3, 8)
sns.set(style="ticks", palette='Set3')
sns.set_style("whitegrid")
sns.boxplot(x='Method', y='Likert Score (1-5)', hue='group', data=data1)
plt.legend(loc='lower center', title="gesture sequence", fontsize= 14)
plt.title('Gesture Distinction (Single Vs Sequential animation)',fontdict = {'fontsize' : 20})
# Out:
# Text(0.5, 1.0, 'Gesture Distinction (Single Vs Sequential animation)')

# %%
fig = plt.figure(figsize = (10,7))
plt.ylim(3, 8)
sns.set(style="ticks", palette='Set3')
sns.set_style("whitegrid")
sns.boxplot(x='Method', y='Likert Score (1-5)', hue='group', data=data2)
plt.legend(loc='lower center', title="gesture sequence", fontsize= 14)
plt.title('Target Distinction (single Vs sequential animation)',fontdict = {'fontsize' : 20})
# Out:
# Text(0.5, 1.0, 'Target Distinction (single Vs sequential animation)')

# %%
fig = plt.figure(figsize = (10,7))
plt.ylim(3, 8)
sns.set(style="ticks", palette='Set3')
sns.set_style("whitegrid")
sns.boxplot(x='Method', y='Likert Score (1-5)', hue='group', data=data3)
plt.legend(loc='lower center', title="gesture sequence", fontsize= 14)
plt.title('Animation Naturalness (single Vs sequential animation)',fontdict = {'fontsize' : 20})
# Out:
# Text(0.5, 1.0, 'Animation Naturalness (single Vs sequential animation)')
